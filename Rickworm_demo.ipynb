# %% [markdown]
# #DEMO

# %% [markdown]
# #Starting off we have our 3 Linux virtual machines: Kali, Ubuntu1, Ubuntu2.
# #These are configured for easy password authentication.
# #The Scenerio: a user on Ubuntu1 clicked on a malicious email link that downloaded the worm.

# %% [markdown]
# ![image.png](attachment:b7b050c1-dd2f-4a4f-8949-7a17af8a7527.png)

# %% [markdown]
# #Executing the worm file on Ubuntu1 for demo. Run ./worm5.py

# %% [markdown]
# ![image.png](attachment:be42eb88-5dbf-44af-a329-a1eeb5ee8044.png)

# %% [markdown]
# #We now see that Ubuntu1 will get rickrolled right away. Shortly it will start scanning for IP addresses.

# %% [markdown]
# ![image.png](attachment:5ba3fabc-a529-4495-b861-1ef9c6226c67.png)

# %% [markdown]
# #Here we see the worm found IP addresses, used the list of passwords and usernames to gain access and copying itself to those machines.
#
#
# #This will also establish cronjobs to run the script for each user based on password legnth.
#
#
# ![image.png](attachment:10157e32-6472-4c78-a066-e8b9a30b656c.png)

# %% [markdown]
# #Next we move on the kali machine.
#
# #We verified the worm was copied over by looking into the /tmp folder
#
# #We also verfied the cronjob was established in a user's profile with crontab -l
#
#
# ![image.png](attachment:6ff8699f-e55f-4f78-9b27-53d4d41eb30f.png)
#
#
# ![image.png](attachment:8022d530-813b-4310-9497-620276afc955.png)

# %% [markdown]
# #Now if someone were to get smart and remove the cronjob from kali, they will be in for a surprise.
#
# #Because the worm also copied itself onto the Ubuntu2 machine in which it will run again. Scanning for the IPs again and then making a copy of itself back onto Kali.
#
#
# ![image.png](attachment:3f818920-e213-4742-8b13-fa142e1a50f8.png)
#
# #You can see how this would be problematic especially in a big enterprise setting.
#
#
#
# #This was a challenging but very rewarding project as our team learned a good bit, but more importantly we had fun!
